# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, confusion_matrix

import os
os.chdir("../")
from Sources.tools import *

# %% [markdown]
# # Load data

# %%
X = pd.read_csv("Data/exctracted_features.csv", sep=";")

# %%
X
# Out:
#      autocorrelation     contrast  cluster_prominence       entropy       SRE  \
# 0       1.028521e+10  267961182.5        4.075990e+18 -3.431037e+07  0.887978
# 1       1.307181e+10  299677314.0        2.310802e+17 -3.284055e+07  0.890659
# 2       1.408697e+10  141461972.5       -2.568155e+18 -3.400099e+07  0.884898
# 3       1.646584e+10  174817302.5        1.638073e+18 -3.286891e+07  0.885616
# 4       1.702260e+10  653435364.0       -2.867736e+18 -2.994633e+07  0.883225
# ..               ...          ...                 ...           ...       ...
# 317     9.288857e+09  366829325.5       -3.380557e+18 -3.752381e+07  0.850045
# 318     1.940154e+10  241357228.0        1.703209e+18 -2.971711e+07  0.886490
# 319     2.011510e+10  234472309.0       -7.601223e+17 -3.023807e+07  0.875200
# 320     1.594847e+10  498173520.5       -1.379895e+18 -3.271282e+07  0.870303
# 321     1.441118e+10  343115688.5       -5.661029e+18 -3.381678e+07  0.863773
#
#              LRE         GLNU     SRLGE       LRLGE
# 0    1346.791926  1337.502577  0.002697   88.638423
# 1    1043.472663  1487.615693  0.002960   72.562531
# 2    1274.675058  1311.839759  0.001111   91.096158
# 3    1017.705164  1558.575770  0.001367   77.164984
# 4     486.280806  3998.275202  0.004939   35.250638
# ..           ...          ...       ...         ...
# 317  2684.590810  1218.974026  0.006298  197.007678
# 318   508.585693  2905.293449  0.001408   44.975496
# 319   573.292162  1985.401396  0.001437   73.324482
# 320   913.247552  2113.820319  0.005579   62.735151
# 321  1181.177769  1818.078512  0.003315   85.811172
#
# [322 rows x 9 columns]

# %%
infos = load_infos()

# %%
infos
# Out:
#     image_idx tissue abnormality severity  x_coord  y_coord  radius
# 0      mdb001      G        CIRC        B      535      425   197.0
# 1      mdb002      G        CIRC        B      522      280    69.0
# 2      mdb003      D        NORM        0        0        0     0.0
# 3      mdb004      D        NORM        0        0        0     0.0
# 4      mdb005      F        CIRC        B      477      133    30.0
# ..        ...    ...         ...      ...      ...      ...     ...
# 325    mdb318      D        NORM        0        0        0     0.0
# 326    mdb319      D        NORM        0        0        0     0.0
# 327    mdb320      D        NORM        0        0        0     0.0
# 328    mdb321      D        NORM        0        0        0     0.0
# 329    mdb322      D        NORM        0        0        0     0.0
#
# [330 rows x 7 columns]

# %%
infos = infos.drop_duplicates(subset=["image_idx"])
y = infos["abnormality"]
y = [1 if ab == "NORM" else 0 for ab in y]

# %% [markdown]
# # Pre process

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# # Model

# %%
model = RandomForestClassifier(random_state=42, max_depth=5)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, random_state=42)

# %% [markdown]
# # Results

# %%
y_pred_train = model.predict(X_train)

metrics_train = compute_classification_metrics(y_train, y_pred_train)
# Out:
# Accuracy: 0.84
# Sensitivity (Recall): 1.00
# Specificity: 0.56
# PPV (Precision): 0.81
# NPV: 1.00
# F1-score: 0.89
# AUC: 0.78
# Balanced Accuracy: 0.78

# %%
y_pred = model.predict(X_test)

metrics_test = compute_classification_metrics(y_test, y_pred)
# Out:
# Accuracy: 0.60
# Sensitivity (Recall): 0.89
# Specificity: 0.06
# PPV (Precision): 0.64
# NPV: 0.22
# F1-score: 0.74
# AUC: 0.47
# Balanced Accuracy: 0.47
